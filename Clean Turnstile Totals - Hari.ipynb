# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %% [markdown]
# # Data Extraction and Cleaning

# %%
from datetime import datetime, date, timedelta
date_start = date(2019,6,1)
date_end = date(2019,6,29)
num_days = (date_end-date_start).days
first_url = ('http://web.mta.info/developers/data/nyct/turnstile/turnstile_'+(date_start).strftime('%y%m%d')+'.txt')
print(first_url)
df = pd.read_csv(first_url)
if num_days > 6:
    for i in range(num_days+1)[7::7]:
        url=('http://web.mta.info/developers/data/nyct/turnstile/turnstile_'+(date_start+timedelta(days=i)).strftime('%y%m%d')+'.txt')
        print(url)
        df = df.append(pd.read_csv(url), ignore_index=True)
# Out:
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_190601.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_190608.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_190615.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_190622.txt
# http://web.mta.info/developers/data/nyct/turnstile/turnstile_190629.txt

# %%
df.head(15)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  20:00:00
# 12  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  00:00:00
# 13  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  04:00:00
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  08:00:00
#
#        DESC  ENTRIES  \
# 0   REGULAR  7071830
# 1   REGULAR  7071844
# 2   REGULAR  7071864
# 3   REGULAR  7071943
# 4   REGULAR  7072182
# 5   REGULAR  7072456
# 6   REGULAR  7072639
# 7   REGULAR  7072662
# 8   REGULAR  7072673
# 9   REGULAR  7072746
# 10  REGULAR  7072929
# 11  REGULAR  7073114
# 12  REGULAR  7073233
# 13  REGULAR  7073244
# 14  REGULAR  7073259
#
#     EXITS
# 0                                             2396411
# 1                                             2396415
# 2                                             2396443
# 3                                             2396500
# 4                                             2396555
# 5                                             2396593
# 6                                             2396608
# 7                                             2396613
# 8                                             2396619
# 9                                             2396665
# 10                                            2396705
# 11                                            2396741
# 12                                            2396759
# 13                                            2396762
# 14                                            2396793

# %%
df.shape
# Out:
# (1027180, 11)

# %%
df = df.rename(index=str, columns={"EXITS                                                               ": "EXITS"})
df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  12:00:00
#
#       DESC  ENTRIES    EXITS
# 0  REGULAR  7071830  2396411
# 1  REGULAR  7071844  2396415
# 2  REGULAR  7071864  2396443
# 3  REGULAR  7071943  2396500
# 4  REGULAR  7072182  2396555
# 5  REGULAR  7072456  2396593
# 6  REGULAR  7072639  2396608
# 7  REGULAR  7072662  2396613
# 8  REGULAR  7072673  2396619
# 9  REGULAR  7072746  2396665

# %%
df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS'],
#       dtype='object')

# %% [markdown]
# ## Totals

# %%
new_df = (df
          .set_index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
       'DESC'])     
          .groupby(['C/A', 'UNIT', 'SCP', 'STATION'])
          .diff(periods=-1))
new_df = new_df.fillna(0)
new_df['ENTRIES'] = -1 * new_df['ENTRIES']
new_df['EXITS'] = -1 * new_df['EXITS']
new_df['TOTALS'] = new_df['ENTRIES'] + new_df['EXITS']
new_df = new_df.reset_index()
new_df
# Out:
#            C/A  UNIT       SCP        STATION LINENAME DIVISION        DATE  \
# 0         A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# 1         A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# 2         A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# 3         A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# 4         A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# 5         A002  R051  02-00-00          59 ST  NQR456W      BMT  05/25/2019
# 6         A002  R051  02-00-00          59 ST  NQR456W      BMT  05/26/2019
# 7         A002  R051  02-00-00          59 ST  NQR456W      BMT  05/26/2019
# 8         A002  R051  02-00-00          59 ST  NQR456W      BMT  05/26/2019
# 9         A002  R051  02-00-00          59 ST  NQR456W      BMT  05/26/2019
# 10        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/26/2019
# 11        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/26/2019
# 12        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/27/2019
# 13        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/27/2019
# 14        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/27/2019
# 15        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/27/2019
# 16        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/27/2019
# 17        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/27/2019
# 18        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/28/2019
# 19        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/28/2019
# 20        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/28/2019
# 21        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/28/2019
# 22        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/28/2019
# 23        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/28/2019
# 24        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/29/2019
# 25        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/29/2019
# 26        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/29/2019
# 27        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/29/2019
# 28        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/29/2019
# 29        A002  R051  02-00-00          59 ST  NQR456W      BMT  05/29/2019
# ...        ...   ...       ...            ...      ...      ...         ...
# 1027150  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2019
# 1027151  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2019
# 1027152  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2019
# 1027153  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2019
# 1027154  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2019
# 1027155  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/24/2019
# 1027156  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/25/2019
# 1027157  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/25/2019
# 1027158  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/25/2019
# 1027159  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/25/2019
# 1027160  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/25/2019
# 1027161  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/25/2019
# 1027162  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/26/2019
# 1027163  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/26/2019
# 1027164  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/26/2019
# 1027165  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/26/2019
# 1027166  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/26/2019
# 1027167  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/26/2019
# 1027168  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/27/2019
# 1027169  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/27/2019
# 1027170  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/27/2019
# 1027171  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/27/2019
# 1027172  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/27/2019
# 1027173  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/27/2019
# 1027174  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/28/2019
# 1027175  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/28/2019
# 1027176  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/28/2019
# 1027177  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/28/2019
# 1027178  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/28/2019
# 1027179  TRAM2  R469  00-05-01  RIT-ROOSEVELT        R      RIT  06/28/2019
#
#              TIME     DESC  ENTRIES  EXITS  TOTALS
# 0        00:00:00  REGULAR     14.0    4.0    18.0
# 1        04:00:00  REGULAR     20.0   28.0    48.0
# 2        08:00:00  REGULAR     79.0   57.0   136.0
# 3        12:00:00  REGULAR    239.0   55.0   294.0
# 4        16:00:00  REGULAR    274.0   38.0   312.0
# 5        20:00:00  REGULAR    183.0   15.0   198.0
# 6        00:00:00  REGULAR     23.0    5.0    28.0
# 7        04:00:00  REGULAR     11.0    6.0    17.0
# 8        08:00:00  REGULAR     73.0   46.0   119.0
# 9        12:00:00  REGULAR    183.0   40.0   223.0
# 10       16:00:00  REGULAR    185.0   36.0   221.0
# 11       20:00:00  REGULAR    119.0   18.0   137.0
# 12       00:00:00  REGULAR     11.0    3.0    14.0
# 13       04:00:00  REGULAR     15.0   31.0    46.0
# 14       08:00:00  REGULAR     79.0   51.0   130.0
# 15       12:00:00  REGULAR    229.0   40.0   269.0
# 16       16:00:00  REGULAR    270.0   35.0   305.0
# 17       20:00:00  REGULAR    130.0   20.0   150.0
# 18       00:00:00  REGULAR      9.0    4.0    13.0
# 19       04:00:00  REGULAR     55.0  113.0   168.0
# 20       08:00:00  REGULAR    175.0  214.0   389.0
# 21       12:00:00  REGULAR    324.0   60.0   384.0
# 22       16:00:00  REGULAR    730.0   80.0   810.0
# 23       20:00:00  REGULAR    200.0   26.0   226.0
# 24       00:00:00  REGULAR     15.0    3.0    18.0
# 25       04:00:00  REGULAR     51.0  102.0   153.0
# 26       08:00:00  REGULAR    188.0  254.0   442.0
# 27       12:00:00  REGULAR    335.0   69.0   404.0
# 28       16:00:00  REGULAR    740.0   80.0   820.0
# 29       20:00:00  REGULAR    196.0   36.0   232.0
# ...           ...      ...      ...    ...     ...
# 1027150  01:00:00  REGULAR      0.0    0.0     0.0
# 1027151  05:00:00  REGULAR      0.0    0.0     0.0
# 1027152  09:00:00  REGULAR      0.0    0.0     0.0
# 1027153  13:00:00  REGULAR      0.0    0.0     0.0
# 1027154  17:00:00  REGULAR      0.0    0.0     0.0
# 1027155  21:00:00  REGULAR      0.0    0.0     0.0
# 1027156  01:00:00  REGULAR      0.0    0.0     0.0
# 1027157  05:00:00  REGULAR      0.0    0.0     0.0
# 1027158  09:00:00  REGULAR      0.0    0.0     0.0
# 1027159  13:00:00  REGULAR      0.0    0.0     0.0
# 1027160  17:00:00  REGULAR      0.0    0.0     0.0
# 1027161  21:00:00  REGULAR      0.0    0.0     0.0
# 1027162  01:00:00  REGULAR      0.0    0.0     0.0
# 1027163  05:00:00  REGULAR      0.0    0.0     0.0
# 1027164  09:00:00  REGULAR      0.0    0.0     0.0
# 1027165  13:00:00  REGULAR      0.0    0.0     0.0
# 1027166  17:00:00  REGULAR      0.0    0.0     0.0
# 1027167  21:00:00  REGULAR      0.0    0.0     0.0
# 1027168  01:00:00  REGULAR      0.0    0.0     0.0
# 1027169  05:00:00  REGULAR      0.0    0.0     0.0
# 1027170  09:00:00  REGULAR      0.0    0.0     0.0
# 1027171  13:00:00  REGULAR      0.0    0.0     0.0
# 1027172  17:00:00  REGULAR      0.0    0.0     0.0
# 1027173  21:00:00  REGULAR      0.0    0.0     0.0
# 1027174  01:00:00  REGULAR      0.0    0.0     0.0
# 1027175  05:00:00  REGULAR      0.0    0.0     0.0
# 1027176  09:00:00  REGULAR      0.0    0.0     0.0
# 1027177  13:00:00  REGULAR      0.0    0.0     0.0
# 1027178  17:00:00  REGULAR      0.0    0.0     0.0
# 1027179  21:00:00  REGULAR      0.0    0.0     0.0
#
# [1027180 rows x 12 columns]

# %%
new_df.columns
# Out:
# Index(['C/A', 'UNIT', 'SCP', 'STATION', 'LINENAME', 'DIVISION', 'DATE', 'TIME',
#        'DESC', 'ENTRIES', 'EXITS', 'TOTALS'],
#       dtype='object')

# %%
new_df.sort_values(by=['TOTALS'], ascending=False)
# Out:
#            C/A  UNIT       SCP          STATION      LINENAME DIVISION  \
# 481766    N207  R104  00-00-00           167 ST            BD      IND
# 788131    R311  R053  00-00-01      3 AV-149 ST            25      IRT
# 1008208   R521  R327  00-06-00            52 ST             7      IRT
# 373847    R293  R133  00-06-01     MOSHOLU PKWY             4      IRT
# 996181    R323  R387  00-00-03    WEST FARMS SQ            25      IRT
# 229684    D009  R393  00-00-02            20 AV             N      BMT
# 531869   PTH17  R541  01-01-00  THIRTY THIRD ST             1      PTH
# 219327    B020  R263  00-03-01         AVENUE H            BQ      BMT
# 472593    N111  R284  00-06-02  CLINTON-WASH AV             C      IND
# 324103   PTH11  R545  00-00-00      14TH STREET             1      PTH
# 113989   PTH02  R544  00-00-00         HARRISON             1      PTH
# 385428    R501  R054  00-00-00            5 AVE         7BDFM      IRT
# 385436    R501  R054  00-00-01            5 AVE         7BDFM      IRT
# 534227   PTH20  R549  03-01-08     NEWARK HM HE             1      PTH
# 385444    R501  R054  00-00-02            5 AVE         7BDFM      IRT
# 385500    R501  R054  00-06-01            5 AVE         7BDFM      IRT
# 544937    R137  R031  02-03-01   34 ST-PENN STA           123      IRT
# 419944    A064  R311  00-03-01           BOWERY            JZ      BMT
# 431624    C021  R212  00-00-00            59 ST           NRW      BMT
# 419922    A064  R311  00-03-00           BOWERY            JZ      BMT
# 326661   PTH17  R541  01-00-05  THIRTY THIRD ST             1      PTH
# 385452    R501  R054  00-00-03            5 AVE         7BDFM      IRT
# 555810    R185  R274  00-00-00           191 ST             1      IRT
# 385492    R501  R054  00-06-00            5 AVE         7BDFM      IRT
# 419900    A064  R311  00-00-00           BOWERY            JZ      BMT
# 329635   PTH22  R540  00-01-00     PATH NEW WTC             1      PTH
# 555842    R185  R274  00-00-01           191 ST             1      IRT
# 239373    H041  R152  00-00-01  CANARSIE-ROCKAW             L      BMT
# 555874    R185  R274  00-00-02           191 ST             1      IRT
# 239445    H041  R152  00-00-03  CANARSIE-ROCKAW             L      BMT
# ...        ...   ...       ...              ...           ...      ...
# 532040   PTH17  R541  01-01-05  THIRTY THIRD ST             1      PTH
# 531814   PTH17  R541  01-00-09  THIRTY THIRD ST             1      PTH
# 527137   PTH05  R543  00-04-03   EXCHANGE PLACE             1      PTH
# 279884    N300  R113  01-00-03             7 AV           BDE      IND
# 530396   PTH13  R541  00-04-05        THIRTY ST             1      PTH
# 619159    A037  R170  05-00-00   14 ST-UNION SQ      LNQR456W      BMT
# 229642    D009  R393  00-00-01            20 AV             N      BMT
# 334835    R113  R028  01-06-00        FULTON ST      2345ACJZ      IRT
# 222278    B028  R136  01-00-02   SHEEPSHEAD BAY            BQ      BMT
# 528849   PTH09  R548  00-00-02   CHRISTOPHER ST             1      PTH
# 531658   PTH17  R541  01-00-05  THIRTY THIRD ST             1      PTH
# 174282    R331  R364  00-00-02      GUN HILL RD            25      IRT
# 482497    N212  R253  01-00-01      174-175 STS            BD      IND
# 464462    N077  R111  02-06-02            23 ST            CE      IND
# 847148    D010  R394  00-00-03         BAY PKWY             N      BMT
# 160148    R243  R049  00-03-03            51 ST             6      IRT
# 714143    N510  R163  02-00-00            14 ST        FLM123      IND
# 679286    N118  R199  01-00-00  KINGSTON-THROOP             C      IND
# 229605    D009  R393  00-00-00            20 AV             N      BMT
# 431728    C021  R212  00-00-03            59 ST           NRW      BMT
# 851744    H001  R175  00-06-00             8 AV          ACEL      BMT
# 460501   N062A  R010  00-06-01  42 ST-PORT AUTH  ACENQRS1237W      IND
# 878503    N087  R282  01-06-01        SPRING ST            CE      IND
# 168234    R291  R183  00-00-00  BEDFORD PK BLVD             4      IRT
# 996182    R323  R387  00-00-03    WEST FARMS SQ            25      IRT
# 714183    N510  R163  02-00-01            14 ST        FLM123      IND
# 1008212   R521  R327  00-06-00            52 ST             7      IRT
# 140413   R160A  R164  00-06-00    66 ST-LINCOLN             1      IRT
# 787793    R310  R053  01-00-02      3 AV-149 ST            25      IRT
# 788088    R311  R053  00-00-00      3 AV-149 ST            25      IRT
#
#                DATE      TIME        DESC       ENTRIES         EXITS  \
# 481766   06/14/2019  12:00:00     REGULAR  1.819016e+09  1.821590e+09
# 788131   06/19/2019  12:00:00     REGULAR  7.019226e+08  1.052777e+09
# 1008208  06/27/2019  13:00:00     REGULAR  7.665461e+08  1.712709e+08
# 373847   06/06/2019  09:00:00     REGULAR  4.511629e+08  6.682709e+07
# 996181   06/25/2019  13:00:00     REGULAR -1.530300e+04  3.355249e+08
# 229684   06/05/2019  09:20:11     REGULAR  3.195804e+06  4.889912e+06
# 531869   06/10/2019  10:00:04     REGULAR  1.692059e+06  8.013130e+05
# 219327   06/07/2019  04:00:00     REGULAR  1.367564e+06  2.460180e+05
# 472593   06/13/2019  00:00:00     REGULAR  8.515010e+05 -2.600000e+02
# 324103   06/07/2019  13:39:06     REGULAR  6.154750e+05  3.844400e+04
# 113989   05/28/2019  10:23:11     REGULAR  3.433470e+05  4.546800e+04
# 385428   06/02/2019  04:00:00     REGULAR  8.009000e+03  2.724300e+04
# 385436   06/02/2019  04:00:00     REGULAR  1.302300e+04  1.283400e+04
# 534227   06/10/2019  10:08:00     REGULAR -8.000000e+00  1.737500e+04
# 385444   06/02/2019  04:00:00     REGULAR  1.068300e+04  6.174000e+03
# 385500   06/02/2019  04:00:00     REGULAR  1.357800e+04  3.228000e+03
# 544937   06/11/2019  06:59:02     REGULAR  0.000000e+00  1.503700e+04
# 419944   06/11/2019  12:00:00     REGULAR  5.978000e+03  5.360000e+03
# 431624   06/10/2019  04:00:00  RECOVR AUD  6.974000e+03  2.954000e+03
# 419922   06/11/2019  12:00:00     REGULAR  4.546000e+03  4.923000e+03
# 326661   06/01/2019  00:04:05     REGULAR  4.951000e+03  4.430000e+03
# 385452   06/02/2019  04:00:00     REGULAR  7.727000e+03  1.116000e+03
# 555810   06/13/2019  04:00:00     REGULAR  2.546000e+03  6.107000e+03
# 385492   06/02/2019  04:00:00     REGULAR  6.709000e+03  1.781000e+03
# 419900   06/11/2019  12:00:00     REGULAR  5.142000e+03  3.123000e+03
# 329635   06/05/2019  05:51:05     REGULAR  6.808000e+03  1.335000e+03
# 555842   06/13/2019  04:00:00     REGULAR  3.414000e+03  4.516000e+03
# 239373   06/06/2019  21:00:00     REGULAR  3.328000e+03  4.029000e+03
# 555874   06/13/2019  04:00:00     REGULAR  3.942000e+03  3.251000e+03
# 239445   06/06/2019  21:00:00     REGULAR  3.704000e+03  3.441000e+03
# ...             ...       ...         ...           ...           ...
# 532040   06/12/2019  05:59:54     REGULAR -2.793245e+06 -9.202800e+05
# 531814   06/12/2019  07:09:10     REGULAR -2.285927e+06 -1.591311e+06
# 527137   06/10/2019  10:57:30     REGULAR -3.126644e+06 -9.820810e+05
# 279884   06/04/2019  21:00:00     REGULAR -2.588118e+06 -1.988151e+06
# 530396   06/11/2019  03:51:48     REGULAR -1.910176e+06 -2.844815e+06
# 619159   06/16/2019  13:00:00     REGULAR -3.124655e+06 -1.662894e+06
# 229642   06/05/2019  09:20:11     REGULAR -1.852963e+06 -2.980961e+06
# 334835   06/06/2019  11:00:00     REGULAR -1.327063e+06 -3.653268e+06
# 222278   06/02/2019  13:00:00  RECOVR AUD -4.317222e+06 -7.389010e+05
# 528849   06/11/2019  11:55:43     REGULAR -2.409760e+06 -2.928014e+06
# 531658   06/12/2019  08:19:10     REGULAR -3.209869e+06 -2.221453e+06
# 174282   05/25/2019  01:00:00     REGULAR -3.000555e+06 -2.654138e+06
# 482497   06/10/2019  08:00:00     REGULAR -4.086559e+06 -1.789843e+06
# 464462   06/14/2019  08:00:00     REGULAR -4.068001e+06 -3.130109e+06
# 847148   06/26/2019  17:00:00  RECOVR AUD -5.328704e+06 -5.978878e+06
# 160148   05/31/2019  20:00:00     REGULAR -7.193693e+06 -4.191585e+06
# 714143   06/18/2019  00:00:00     REGULAR -4.676669e+06 -7.278332e+06
# 679286   06/19/2019  20:00:00     REGULAR -3.466208e+06 -9.433779e+06
# 229605   06/05/2019  09:20:11     REGULAR -7.246147e+06 -6.668527e+06
# 431728   06/09/2019  16:00:00     REGULAR -1.396740e+07 -1.461197e+07
# 851744   06/24/2019  01:00:00     REGULAR -5.643297e+07 -1.988408e+07
# 460501   06/14/2019  10:00:00     REGULAR -9.903737e+07 -4.576563e+06
# 878503   06/27/2019  20:00:00     REGULAR -1.173906e+08 -4.130700e+04
# 168234   05/29/2019  00:00:00     REGULAR -2.039775e+08 -1.361487e+06
# 996182   06/25/2019  17:00:00  RECOVR AUD  1.580400e+04 -3.355247e+08
# 714183   06/18/2019  00:00:00     REGULAR -6.214849e+08 -3.695330e+08
# 1008212  06/28/2019  05:00:00     REGULAR -8.678275e+08 -1.743245e+08
# 140413   05/31/2019  05:00:00     REGULAR -1.661416e+09 -3.861678e+08
# 787793   06/19/2019  12:00:00     REGULAR -1.061119e+09 -1.136398e+09
# 788088   06/19/2019  12:00:00     REGULAR -1.169827e+09 -1.353647e+09
#
#                TOTALS
# 481766   3.640606e+09
# 788131   1.754699e+09
# 1008208  9.378169e+08
# 373847   5.179900e+08
# 996181   3.355096e+08
# 229684   8.085716e+06
# 531869   2.493372e+06
# 219327   1.613582e+06
# 472593   8.512410e+05
# 324103   6.539190e+05
# 113989   3.888150e+05
# 385428   3.525200e+04
# 385436   2.585700e+04
# 534227   1.736700e+04
# 385444   1.685700e+04
# 385500   1.680600e+04
# 544937   1.503700e+04
# 419944   1.133800e+04
# 431624   9.928000e+03
# 419922   9.469000e+03
# 326661   9.381000e+03
# 385452   8.843000e+03
# 555810   8.653000e+03
# 385492   8.490000e+03
# 419900   8.265000e+03
# 329635   8.143000e+03
# 555842   7.930000e+03
# 239373   7.357000e+03
# 555874   7.193000e+03
# 239445   7.145000e+03
# ...               ...
# 532040  -3.713525e+06
# 531814  -3.877238e+06
# 527137  -4.108725e+06
# 279884  -4.576269e+06
# 530396  -4.754991e+06
# 619159  -4.787549e+06
# 229642  -4.833924e+06
# 334835  -4.980331e+06
# 222278  -5.056123e+06
# 528849  -5.337774e+06
# 531658  -5.431322e+06
# 174282  -5.654693e+06
# 482497  -5.876402e+06
# 464462  -7.198110e+06
# 847148  -1.130758e+07
# 160148  -1.138528e+07
# 714143  -1.195500e+07
# 679286  -1.289999e+07
# 229605  -1.391467e+07
# 431728  -2.857937e+07
# 851744  -7.631705e+07
# 460501  -1.036139e+08
# 878503  -1.174319e+08
# 168234  -2.053390e+08
# 996182  -3.355089e+08
# 714183  -9.910179e+08
# 1008212 -1.042152e+09
# 140413  -2.047584e+09
# 787793  -2.197517e+09
# 788088  -2.523473e+09
#
# [1027180 rows x 12 columns]

# %%
new_df.shape
# Out:
# (1027180, 12)

# %%
new_df = new_df.loc[new_df['TOTALS'] < 5000]
new_df = new_df.loc[new_df['TOTALS'] >= 0]
new_df = new_df.loc[new_df['EXITS'] >= 0]
new_df = new_df.loc[new_df['ENTRIES'] >= 0]
new_df.head(15)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
# 5   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  20:00:00
# 6   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  00:00:00
# 7   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  04:00:00
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  08:00:00
# 9   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  12:00:00
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  16:00:00
# 11  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  20:00:00
# 12  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  00:00:00
# 13  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  04:00:00
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019  08:00:00
#
#        DESC  ENTRIES  EXITS  TOTALS
# 0   REGULAR     14.0    4.0    18.0
# 1   REGULAR     20.0   28.0    48.0
# 2   REGULAR     79.0   57.0   136.0
# 3   REGULAR    239.0   55.0   294.0
# 4   REGULAR    274.0   38.0   312.0
# 5   REGULAR    183.0   15.0   198.0
# 6   REGULAR     23.0    5.0    28.0
# 7   REGULAR     11.0    6.0    17.0
# 8   REGULAR     73.0   46.0   119.0
# 9   REGULAR    183.0   40.0   223.0
# 10  REGULAR    185.0   36.0   221.0
# 11  REGULAR    119.0   18.0   137.0
# 12  REGULAR     11.0    3.0    14.0
# 13  REGULAR     15.0   31.0    46.0
# 14  REGULAR     79.0   51.0   130.0

# %%
new_df['DESC'].unique()
# Out:
# array(['REGULAR', 'RECOVR AUD'], dtype=object)

# %%
new_df.shape
# Out:
# (1014259, 12)

# %%
new_df = new_df.drop_duplicates(subset=['C/A', 'UNIT', 'SCP', 'STATION', 'DATE', 'TIME'])
new_df.shape
# Out:
# (1014253, 12)

# %%
new_df.describe()
# Out:
#             ENTRIES         EXITS        TOTALS
# count  1.014253e+06  1.014253e+06  1.014253e+06
# mean   1.698375e+02  1.356986e+02  3.055360e+02
# std    2.470192e+02  2.302705e+02  3.830327e+02
# min    0.000000e+00  0.000000e+00  0.000000e+00
# 25%    9.000000e+00  8.000000e+00  2.900000e+01
# 50%    7.200000e+01  5.200000e+01  1.680000e+02
# 75%    2.330000e+02  1.640000e+02  4.440000e+02
# max    3.963000e+03  4.753000e+03  4.838000e+03

# %% [markdown]
# ## Timestamp

# %%
new_df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  12:00:00
#
#       DESC  ENTRIES  EXITS  TOTALS
# 0  REGULAR     14.0    4.0    18.0
# 1  REGULAR     20.0   28.0    48.0
# 2  REGULAR     79.0   57.0   136.0
# 3  REGULAR    239.0   55.0   294.0
# 4  REGULAR    274.0   38.0   312.0
# 5  REGULAR    183.0   15.0   198.0
# 6  REGULAR     23.0    5.0    28.0
# 7  REGULAR     11.0    6.0    17.0
# 8  REGULAR     73.0   46.0   119.0
# 9  REGULAR    183.0   40.0   223.0

# %%
new_df['DATETIME'] = new_df['DATE'] + ' ' + new_df['TIME']
new_df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  12:00:00
#
#       DESC  ENTRIES  EXITS  TOTALS             DATETIME
# 0  REGULAR     14.0    4.0    18.0  05/25/2019 00:00:00
# 1  REGULAR     20.0   28.0    48.0  05/25/2019 04:00:00
# 2  REGULAR     79.0   57.0   136.0  05/25/2019 08:00:00
# 3  REGULAR    239.0   55.0   294.0  05/25/2019 12:00:00
# 4  REGULAR    274.0   38.0   312.0  05/25/2019 16:00:00
# 5  REGULAR    183.0   15.0   198.0  05/25/2019 20:00:00
# 6  REGULAR     23.0    5.0    28.0  05/26/2019 00:00:00
# 7  REGULAR     11.0    6.0    17.0  05/26/2019 04:00:00
# 8  REGULAR     73.0   46.0   119.0  05/26/2019 08:00:00
# 9  REGULAR    183.0   40.0   223.0  05/26/2019 12:00:00

# %%
new_df['DATETIME1'] = pd.to_datetime(new_df['DATETIME'])
new_df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  12:00:00
#
#       DESC  ENTRIES  EXITS  TOTALS             DATETIME           DATETIME1
# 0  REGULAR     14.0    4.0    18.0  05/25/2019 00:00:00 2019-05-25 00:00:00
# 1  REGULAR     20.0   28.0    48.0  05/25/2019 04:00:00 2019-05-25 04:00:00
# 2  REGULAR     79.0   57.0   136.0  05/25/2019 08:00:00 2019-05-25 08:00:00
# 3  REGULAR    239.0   55.0   294.0  05/25/2019 12:00:00 2019-05-25 12:00:00
# 4  REGULAR    274.0   38.0   312.0  05/25/2019 16:00:00 2019-05-25 16:00:00
# 5  REGULAR    183.0   15.0   198.0  05/25/2019 20:00:00 2019-05-25 20:00:00
# 6  REGULAR     23.0    5.0    28.0  05/26/2019 00:00:00 2019-05-26 00:00:00
# 7  REGULAR     11.0    6.0    17.0  05/26/2019 04:00:00 2019-05-26 04:00:00
# 8  REGULAR     73.0   46.0   119.0  05/26/2019 08:00:00 2019-05-26 08:00:00
# 9  REGULAR    183.0   40.0   223.0  05/26/2019 12:00:00 2019-05-26 12:00:00

# %%
new_df['WEEKDAY'] = new_df['DATETIME1'].dt.weekday_name
new_df['WEEKDAYNUM'] = new_df['DATETIME1'].dt.weekday
new_df['HOUR'] = new_df['DATETIME1'].dt.hour
new_df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE      TIME  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  00:00:00
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  04:00:00
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  08:00:00
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  12:00:00
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  16:00:00
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019  20:00:00
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  00:00:00
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  04:00:00
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  08:00:00
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019  12:00:00
#
#       DESC  ENTRIES  EXITS  TOTALS             DATETIME           DATETIME1  \
# 0  REGULAR     14.0    4.0    18.0  05/25/2019 00:00:00 2019-05-25 00:00:00
# 1  REGULAR     20.0   28.0    48.0  05/25/2019 04:00:00 2019-05-25 04:00:00
# 2  REGULAR     79.0   57.0   136.0  05/25/2019 08:00:00 2019-05-25 08:00:00
# 3  REGULAR    239.0   55.0   294.0  05/25/2019 12:00:00 2019-05-25 12:00:00
# 4  REGULAR    274.0   38.0   312.0  05/25/2019 16:00:00 2019-05-25 16:00:00
# 5  REGULAR    183.0   15.0   198.0  05/25/2019 20:00:00 2019-05-25 20:00:00
# 6  REGULAR     23.0    5.0    28.0  05/26/2019 00:00:00 2019-05-26 00:00:00
# 7  REGULAR     11.0    6.0    17.0  05/26/2019 04:00:00 2019-05-26 04:00:00
# 8  REGULAR     73.0   46.0   119.0  05/26/2019 08:00:00 2019-05-26 08:00:00
# 9  REGULAR    183.0   40.0   223.0  05/26/2019 12:00:00 2019-05-26 12:00:00
#
#     WEEKDAY  WEEKDAYNUM  HOUR
# 0  Saturday           5     0
# 1  Saturday           5     4
# 2  Saturday           5     8
# 3  Saturday           5    12
# 4  Saturday           5    16
# 5  Saturday           5    20
# 6    Sunday           6     0
# 7    Sunday           6     4
# 8    Sunday           6     8
# 9    Sunday           6    12

# %%
new_df["TIME"] = new_df['HOUR'].map({8 : "8:00am - 12:00am", 16 : "4:00pm - 8:00pm",
                 9 : "8:00am - 12:00am", 10 : "8:00am - 12:00am", 17 : "4:00pm - 8:00pm", 18 : "4:00pm - 8:00pm",
                 11: "8:00am - 12:00am", 19 :"4:00pm - 8:00pm"})
new_df.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019
#
#                TIME     DESC  ENTRIES  EXITS  TOTALS             DATETIME  \
# 0               NaN  REGULAR     14.0    4.0    18.0  05/25/2019 00:00:00
# 1               NaN  REGULAR     20.0   28.0    48.0  05/25/2019 04:00:00
# 2  8:00am - 12:00am  REGULAR     79.0   57.0   136.0  05/25/2019 08:00:00
# 3               NaN  REGULAR    239.0   55.0   294.0  05/25/2019 12:00:00
# 4   4:00pm - 8:00pm  REGULAR    274.0   38.0   312.0  05/25/2019 16:00:00
# 5               NaN  REGULAR    183.0   15.0   198.0  05/25/2019 20:00:00
# 6               NaN  REGULAR     23.0    5.0    28.0  05/26/2019 00:00:00
# 7               NaN  REGULAR     11.0    6.0    17.0  05/26/2019 04:00:00
# 8  8:00am - 12:00am  REGULAR     73.0   46.0   119.0  05/26/2019 08:00:00
# 9               NaN  REGULAR    183.0   40.0   223.0  05/26/2019 12:00:00
#
#             DATETIME1   WEEKDAY  WEEKDAYNUM  HOUR
# 0 2019-05-25 00:00:00  Saturday           5     0
# 1 2019-05-25 04:00:00  Saturday           5     4
# 2 2019-05-25 08:00:00  Saturday           5     8
# 3 2019-05-25 12:00:00  Saturday           5    12
# 4 2019-05-25 16:00:00  Saturday           5    16
# 5 2019-05-25 20:00:00  Saturday           5    20
# 6 2019-05-26 00:00:00    Sunday           6     0
# 7 2019-05-26 04:00:00    Sunday           6     4
# 8 2019-05-26 08:00:00    Sunday           6     8
# 9 2019-05-26 12:00:00    Sunday           6    12

# %%
new_df = new_df.dropna()
new_df.head(10)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019
# 16  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019
# 20  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019
# 22  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019
# 26  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019
# 28  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019
#
#                 TIME     DESC  ENTRIES  EXITS  TOTALS             DATETIME  \
# 2   8:00am - 12:00am  REGULAR     79.0   57.0   136.0  05/25/2019 08:00:00
# 4    4:00pm - 8:00pm  REGULAR    274.0   38.0   312.0  05/25/2019 16:00:00
# 8   8:00am - 12:00am  REGULAR     73.0   46.0   119.0  05/26/2019 08:00:00
# 10   4:00pm - 8:00pm  REGULAR    185.0   36.0   221.0  05/26/2019 16:00:00
# 14  8:00am - 12:00am  REGULAR     79.0   51.0   130.0  05/27/2019 08:00:00
# 16   4:00pm - 8:00pm  REGULAR    270.0   35.0   305.0  05/27/2019 16:00:00
# 20  8:00am - 12:00am  REGULAR    175.0  214.0   389.0  05/28/2019 08:00:00
# 22   4:00pm - 8:00pm  REGULAR    730.0   80.0   810.0  05/28/2019 16:00:00
# 26  8:00am - 12:00am  REGULAR    188.0  254.0   442.0  05/29/2019 08:00:00
# 28   4:00pm - 8:00pm  REGULAR    740.0   80.0   820.0  05/29/2019 16:00:00
#
#              DATETIME1    WEEKDAY  WEEKDAYNUM  HOUR
# 2  2019-05-25 08:00:00   Saturday           5     8
# 4  2019-05-25 16:00:00   Saturday           5    16
# 8  2019-05-26 08:00:00     Sunday           6     8
# 10 2019-05-26 16:00:00     Sunday           6    16
# 14 2019-05-27 08:00:00     Monday           0     8
# 16 2019-05-27 16:00:00     Monday           0    16
# 20 2019-05-28 08:00:00    Tuesday           1     8
# 22 2019-05-28 16:00:00    Tuesday           1    16
# 26 2019-05-29 08:00:00  Wednesday           2     8
# 28 2019-05-29 16:00:00  Wednesday           2    16

# %%
new_df.describe()
# Out:
#              ENTRIES          EXITS         TOTALS     WEEKDAYNUM  \
# count  342074.000000  342074.000000  342074.000000  342074.000000
# mean      247.435868     206.282579     453.718447       2.991014
# std       303.873483     300.946481     467.032595       1.993246
# min         0.000000       0.000000       0.000000       0.000000
# 25%        40.000000      25.000000     111.000000       1.000000
# 50%       150.000000     103.000000     322.000000       3.000000
# 75%       339.000000     264.000000     655.000000       5.000000
# max      3963.000000    4753.000000    4838.000000       6.000000
#
#                 HOUR
# count  342074.000000
# mean       12.495557
# std         4.055044
# min         8.000000
# 25%         8.000000
# 50%        11.000000
# 75%        16.000000
# max        19.000000

# %%
import pickle

with open('clean_turnstile.pickle', 'wb') as to_write:
    pickle.dump(new_df, to_write)

# %%
# !ls
# Out:
# Clean Turnstile Totals.ipynb README.md
# Joel_EDA.ipynb               clean_turnstile.pickle

# %% [markdown]
# # Analysis

# %%
with open('clean_turnstile.pickle','rb') as read_file:
    new_df = pickle.load(read_file)

# %%
station_df = new_df.groupby('STATION', as_index=False)['TOTALS'].sum()
station_df = station_df.sort_values(by=['TOTALS'], ascending=False)
station_df.head(20)
# Out:
#              STATION     TOTALS
# 61    34 ST-PENN STA  5082815.0
# 232  GRD CNTRL-42 ST  4617833.0
# 59   34 ST-HERALD SQ  4047619.0
# 352   TIMES SQ-42 ST  3366562.0
# 46             23 ST  3262054.0
# 14    14 ST-UNION SQ  2988466.0
# 68   42 ST-PORT AUTH  2613391.0
# 110            86 ST  2514416.0
# 225        FULTON ST  2442310.0
# 172         CANAL ST  2330014.0
# 72    47-50 STS ROCK  2299069.0
# 86    59 ST COLUMBUS  2172026.0
# 9             125 ST  2004687.0
# 85             59 ST  2002550.0
# 115            96 ST  1770330.0
# 13             14 ST  1760439.0
# 179      CHAMBERS ST  1706856.0
# 216    FLUSHING-MAIN  1677613.0
# 78             50 ST  1602659.0
# 67   42 ST-BRYANT PK  1551800.0

# %%
plt.figure(figsize=(10,10))
top_ten_station = station_df[0:15]
plt.barh(top_ten_station['STATION'],top_ten_station['TOTALS'])
plt.xlabel('Number of People')
plt.ylabel('Station')
plt.title('Top 15 Stations With Highest Traffic')
for i, v in enumerate(top_ten_station['TOTALS']):
    plt.text(v-500000, i-0.2, str(round(v)), color='white', fontweight='bold')

# %%
new_df.head(15)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 2   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019
# 4   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/25/2019
# 8   A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019
# 10  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/26/2019
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019
# 16  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019
# 20  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019
# 22  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019
# 26  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019
# 28  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019
# 32  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/30/2019
# 34  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/30/2019
# 38  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/31/2019
# 40  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/31/2019
# 44  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/25/2019
#
#                 TIME     DESC  ENTRIES  EXITS  TOTALS             DATETIME  \
# 2   8:00am - 12:00am  REGULAR     79.0   57.0   136.0  05/25/2019 08:00:00
# 4    4:00pm - 8:00pm  REGULAR    274.0   38.0   312.0  05/25/2019 16:00:00
# 8   8:00am - 12:00am  REGULAR     73.0   46.0   119.0  05/26/2019 08:00:00
# 10   4:00pm - 8:00pm  REGULAR    185.0   36.0   221.0  05/26/2019 16:00:00
# 14  8:00am - 12:00am  REGULAR     79.0   51.0   130.0  05/27/2019 08:00:00
# 16   4:00pm - 8:00pm  REGULAR    270.0   35.0   305.0  05/27/2019 16:00:00
# 20  8:00am - 12:00am  REGULAR    175.0  214.0   389.0  05/28/2019 08:00:00
# 22   4:00pm - 8:00pm  REGULAR    730.0   80.0   810.0  05/28/2019 16:00:00
# 26  8:00am - 12:00am  REGULAR    188.0  254.0   442.0  05/29/2019 08:00:00
# 28   4:00pm - 8:00pm  REGULAR    740.0   80.0   820.0  05/29/2019 16:00:00
# 32  8:00am - 12:00am  REGULAR    183.0  199.0   382.0  05/30/2019 08:00:00
# 34   4:00pm - 8:00pm  REGULAR    719.0   95.0   814.0  05/30/2019 16:00:00
# 38  8:00am - 12:00am  REGULAR    198.0  165.0   363.0  05/31/2019 08:00:00
# 40   4:00pm - 8:00pm  REGULAR    767.0   78.0   845.0  05/31/2019 16:00:00
# 44  8:00am - 12:00am  REGULAR     76.0   41.0   117.0  05/25/2019 08:00:00
#
#              DATETIME1    WEEKDAY  WEEKDAYNUM  HOUR
# 2  2019-05-25 08:00:00   Saturday           5     8
# 4  2019-05-25 16:00:00   Saturday           5    16
# 8  2019-05-26 08:00:00     Sunday           6     8
# 10 2019-05-26 16:00:00     Sunday           6    16
# 14 2019-05-27 08:00:00     Monday           0     8
# 16 2019-05-27 16:00:00     Monday           0    16
# 20 2019-05-28 08:00:00    Tuesday           1     8
# 22 2019-05-28 16:00:00    Tuesday           1    16
# 26 2019-05-29 08:00:00  Wednesday           2     8
# 28 2019-05-29 16:00:00  Wednesday           2    16
# 32 2019-05-30 08:00:00   Thursday           3     8
# 34 2019-05-30 16:00:00   Thursday           3    16
# 38 2019-05-31 08:00:00     Friday           4     8
# 40 2019-05-31 16:00:00     Friday           4    16
# 44 2019-05-25 08:00:00   Saturday           5     8

# %%
mean_totals_df = new_df.groupby(['DATE', 'TIME'])['TOTALS'].agg({'mean'})
mean_totals_df = mean_totals_df.reset_index()
mean_totals_df.head(15)
# Out:
#           DATE              TIME        mean
# 0   05/25/2019   4:00pm - 8:00pm  319.100837
# 1   05/25/2019  8:00am - 12:00am  237.934924
# 2   05/26/2019   4:00pm - 8:00pm  271.144707
# 3   05/26/2019  8:00am - 12:00am  209.406485
# 4   05/27/2019   4:00pm - 8:00pm  275.393494
# 5   05/27/2019  8:00am - 12:00am  204.228005
# 6   05/28/2019   4:00pm - 8:00pm  618.591179
# 7   05/28/2019  8:00am - 12:00am  478.840177
# 8   05/29/2019   4:00pm - 8:00pm  636.619631
# 9   05/29/2019  8:00am - 12:00am  500.596029
# 10  05/30/2019   4:00pm - 8:00pm  637.947522
# 11  05/30/2019  8:00am - 12:00am  490.160674
# 12  05/31/2019   4:00pm - 8:00pm  599.144665
# 13  05/31/2019  8:00am - 12:00am  433.857382
# 14  06/01/2019   4:00pm - 8:00pm  322.518813

# %%
# %matplotlib inline

morning_rush_df = mean_totals_df.loc[mean_totals_df['TIME'] == '8:00am - 12:00am']
afternoon_rush_df = mean_totals_df.loc[mean_totals_df['TIME'] == '4:00pm - 8:00pm']

import matplotlib.pyplot as plt
plt.figure(figsize=(16,4))
plt.plot(morning_rush_df['DATE'],morning_rush_df['mean'])
plt.plot(afternoon_rush_df ['DATE'],afternoon_rush_df['mean'])
plt.title('Average Number of Users Taking Metro from 5/25/2019-6/28/2019')
plt.xlabel('Date')
plt.xticks(rotation=90)
plt.ylabel('Number of Users')
plt.legend(['Morning Rush Hour', 'Afternoon Rush Hour'], shadow = True, loc = 0);

# %%
weekday_mean_totals_df = (new_df
                          .groupby(['WEEKDAY', 'TIME', 'WEEKDAYNUM'])['TOTALS']
                          .agg({'mean'}))
weekday_mean_totals_df = weekday_mean_totals_df.reset_index()

weekday_mean_totals_df= weekday_mean_totals_df.sort_values(by=['WEEKDAYNUM'])
weekday_mean_totals_df= weekday_mean_totals_df.drop('WEEKDAYNUM', axis=1)

weekday_mean_totals_df.head(15)
# Out:
#       WEEKDAY              TIME        mean
# 2      Monday   4:00pm - 8:00pm  533.863340
# 3      Monday  8:00am - 12:00am  412.420759
# 10    Tuesday   4:00pm - 8:00pm  629.042131
# 11    Tuesday  8:00am - 12:00am  473.074887
# 12  Wednesday   4:00pm - 8:00pm  643.949965
# 13  Wednesday  8:00am - 12:00am  483.142040
# 8    Thursday   4:00pm - 8:00pm  628.832509
# 9    Thursday  8:00am - 12:00am  483.017119
# 0      Friday   4:00pm - 8:00pm  584.878409
# 1      Friday  8:00am - 12:00am  445.141517
# 4    Saturday   4:00pm - 8:00pm  327.850081
# 5    Saturday  8:00am - 12:00am  243.221973
# 6      Sunday   4:00pm - 8:00pm  263.137878
# 7      Sunday  8:00am - 12:00am  201.827537

# %%
morning_rush_weekday_df = weekday_mean_totals_df.loc[weekday_mean_totals_df['TIME'] == '8:00am - 12:00am']
morning_rush_weekday_df
# Out:
#       WEEKDAY              TIME        mean
# 3      Monday  8:00am - 12:00am  412.420759
# 11    Tuesday  8:00am - 12:00am  473.074887
# 13  Wednesday  8:00am - 12:00am  483.142040
# 9    Thursday  8:00am - 12:00am  483.017119
# 1      Friday  8:00am - 12:00am  445.141517
# 5    Saturday  8:00am - 12:00am  243.221973
# 7      Sunday  8:00am - 12:00am  201.827537

# %%
afternoon_rush_weekday_df = weekday_mean_totals_df.loc[weekday_mean_totals_df['TIME'] == '4:00pm - 8:00pm']
afternoon_rush_weekday_df
# Out:
#       WEEKDAY             TIME        mean
# 2      Monday  4:00pm - 8:00pm  533.863340
# 10    Tuesday  4:00pm - 8:00pm  629.042131
# 12  Wednesday  4:00pm - 8:00pm  643.949965
# 8    Thursday  4:00pm - 8:00pm  628.832509
# 0      Friday  4:00pm - 8:00pm  584.878409
# 4    Saturday  4:00pm - 8:00pm  327.850081
# 6      Sunday  4:00pm - 8:00pm  263.137878

# %%
plt.figure(figsize=(13,3))
plt.plot(morning_rush_weekday_df['WEEKDAY'], morning_rush_weekday_df['mean'])
plt.plot(afternoon_rush_weekday_df['WEEKDAY'], afternoon_rush_weekday_df['mean'])
plt.title('Average Number of Users Taking Metro per Day')
plt.xlabel('Day')
plt.xticks(rotation=90)
plt.ylabel('Number of Users')
plt.legend(['Morning Rush Hour', 'Afternoon Rush Hour'], shadow = True, loc = 0)

# %%
weekday_df = new_df.loc[(new_df['WEEKDAY'] != 'Saturday') & (new_df['WEEKDAY'] != 'Sunday')]
weekday_df.head(20)
# Out:
#      C/A  UNIT       SCP STATION LINENAME DIVISION        DATE  \
# 14  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019
# 16  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/27/2019
# 20  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019
# 22  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/28/2019
# 26  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019
# 28  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/29/2019
# 32  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/30/2019
# 34  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/30/2019
# 38  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/31/2019
# 40  A002  R051  02-00-00   59 ST  NQR456W      BMT  05/31/2019
# 56  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/27/2019
# 58  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/27/2019
# 62  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/28/2019
# 64  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/28/2019
# 68  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/29/2019
# 70  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/29/2019
# 74  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/30/2019
# 76  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/30/2019
# 80  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/31/2019
# 82  A002  R051  02-00-01   59 ST  NQR456W      BMT  05/31/2019
#
#                 TIME     DESC  ENTRIES  EXITS  TOTALS             DATETIME  \
# 14  8:00am - 12:00am  REGULAR     79.0   51.0   130.0  05/27/2019 08:00:00
# 16   4:00pm - 8:00pm  REGULAR    270.0   35.0   305.0  05/27/2019 16:00:00
# 20  8:00am - 12:00am  REGULAR    175.0  214.0   389.0  05/28/2019 08:00:00
# 22   4:00pm - 8:00pm  REGULAR    730.0   80.0   810.0  05/28/2019 16:00:00
# 26  8:00am - 12:00am  REGULAR    188.0  254.0   442.0  05/29/2019 08:00:00
# 28   4:00pm - 8:00pm  REGULAR    740.0   80.0   820.0  05/29/2019 16:00:00
# 32  8:00am - 12:00am  REGULAR    183.0  199.0   382.0  05/30/2019 08:00:00
# 34   4:00pm - 8:00pm  REGULAR    719.0   95.0   814.0  05/30/2019 16:00:00
# 38  8:00am - 12:00am  REGULAR    198.0  165.0   363.0  05/31/2019 08:00:00
# 40   4:00pm - 8:00pm  REGULAR    767.0   78.0   845.0  05/31/2019 16:00:00
# 56  8:00am - 12:00am  REGULAR     64.0   34.0    98.0  05/27/2019 08:00:00
# 58   4:00pm - 8:00pm  REGULAR    188.0   28.0   216.0  05/27/2019 16:00:00
# 62  8:00am - 12:00am  REGULAR    177.0  126.0   303.0  05/28/2019 08:00:00
# 64   4:00pm - 8:00pm  REGULAR    649.0   71.0   720.0  05/28/2019 16:00:00
# 68  8:00am - 12:00am  REGULAR    160.0  134.0   294.0  05/29/2019 08:00:00
# 70   4:00pm - 8:00pm  REGULAR    630.0   66.0   696.0  05/29/2019 16:00:00
# 74  8:00am - 12:00am  REGULAR    160.0  111.0   271.0  05/30/2019 08:00:00
# 76   4:00pm - 8:00pm  REGULAR    654.0   55.0   709.0  05/30/2019 16:00:00
# 80  8:00am - 12:00am  REGULAR    145.0  107.0   252.0  05/31/2019 08:00:00
# 82   4:00pm - 8:00pm  REGULAR    624.0   54.0   678.0  05/31/2019 16:00:00
#
#              DATETIME1    WEEKDAY  WEEKDAYNUM  HOUR
# 14 2019-05-27 08:00:00     Monday           0     8
# 16 2019-05-27 16:00:00     Monday           0    16
# 20 2019-05-28 08:00:00    Tuesday           1     8
# 22 2019-05-28 16:00:00    Tuesday           1    16
# 26 2019-05-29 08:00:00  Wednesday           2     8
# 28 2019-05-29 16:00:00  Wednesday           2    16
# 32 2019-05-30 08:00:00   Thursday           3     8
# 34 2019-05-30 16:00:00   Thursday           3    16
# 38 2019-05-31 08:00:00     Friday           4     8
# 40 2019-05-31 16:00:00     Friday           4    16
# 56 2019-05-27 08:00:00     Monday           0     8
# 58 2019-05-27 16:00:00     Monday           0    16
# 62 2019-05-28 08:00:00    Tuesday           1     8
# 64 2019-05-28 16:00:00    Tuesday           1    16
# 68 2019-05-29 08:00:00  Wednesday           2     8
# 70 2019-05-29 16:00:00  Wednesday           2    16
# 74 2019-05-30 08:00:00   Thursday           3     8
# 76 2019-05-30 16:00:00   Thursday           3    16
# 80 2019-05-31 08:00:00     Friday           4     8
# 82 2019-05-31 16:00:00     Friday           4    16

# %%
#station_mean_totals_df.loc[station_mean_totals_df['TIME'] == '8:00am - 12:00am']
#station_mean_totals_df = new_df.groupby(['STATION', 'DATE', 'TIME'])['TOTALS'].agg({'sum'})
station_mean_totals_df = weekday_df.groupby(['STATION', 'DATE', 'TIME'])['TOTALS'].agg({'sum'})
station_mean_totals_df = station_mean_totals_df.reset_index()
station_mean_totals_df = station_mean_totals_df.rename(columns={'sum': 'USERS'})
station_mean_totals_df.head(15)
# Out:
#    STATION        DATE              TIME    USERS
# 0     1 AV  05/27/2019   4:00pm - 8:00pm   3185.0
# 1     1 AV  05/27/2019  8:00am - 12:00am   1722.0
# 2     1 AV  05/28/2019   4:00pm - 8:00pm  11779.0
# 3     1 AV  05/28/2019  8:00am - 12:00am   9710.0
# 4     1 AV  05/29/2019   4:00pm - 8:00pm  13778.0
# 5     1 AV  05/29/2019  8:00am - 12:00am  10081.0
# 6     1 AV  05/30/2019   4:00pm - 8:00pm  14072.0
# 7     1 AV  05/30/2019  8:00am - 12:00am   9984.0
# 8     1 AV  05/31/2019   4:00pm - 8:00pm  12594.0
# 9     1 AV  05/31/2019  8:00am - 12:00am   9875.0
# 10    1 AV  06/03/2019   4:00pm - 8:00pm  11962.0
# 11    1 AV  06/03/2019  8:00am - 12:00am   9438.0
# 12    1 AV  06/04/2019   4:00pm - 8:00pm  11787.0
# 13    1 AV  06/04/2019  8:00am - 12:00am   8731.0
# 14    1 AV  06/05/2019   4:00pm - 8:00pm  12396.0

# %%
station_mean_totals_df_morning_rush = station_mean_totals_df.loc[station_mean_totals_df['TIME'] == '8:00am - 12:00am']
station_mean_totals_df_afternoon_rush = station_mean_totals_df.loc[station_mean_totals_df['TIME'] == '4:00pm - 8:00pm']

# %%
top_station_means_morning_rush_df = station_mean_totals_df_morning_rush.groupby('STATION')['USERS'].agg({'mean'}).sort_values(by=['mean'], ascending=False).reset_index()
top_station_means_morning_rush_df.head(15)
# Out:
#             STATION      mean
# 0    34 ST-PENN STA  77028.60
# 1   GRD CNTRL-42 ST  70853.72
# 2   34 ST-HERALD SQ  57403.56
# 3    TIMES SQ-42 ST  48892.24
# 4             23 ST  48335.40
# 5    47-50 STS ROCK  40323.84
# 6    14 ST-UNION SQ  40313.52
# 7             86 ST  37741.72
# 8   42 ST-PORT AUTH  37554.08
# 9         FULTON ST  37478.44
# 10         CANAL ST  32222.60
# 11            59 ST  31637.48
# 12   59 ST COLUMBUS  30595.72
# 13           125 ST  28784.00
# 14  LEXINGTON AV/53  27770.28

# %%
top_station_means_afternoon_rush_df = station_mean_totals_df_afternoon_rush.groupby('STATION')['USERS'].agg({'mean'}).sort_values(by=['mean'], ascending=False).reset_index()
top_station_means_afternoon_rush_df.head(15)
# Out:
#             STATION      mean
# 0    34 ST-PENN STA  95875.72
# 1   GRD CNTRL-42 ST  93888.48
# 2   34 ST-HERALD SQ  81326.04
# 3    TIMES SQ-42 ST  66139.40
# 4             23 ST  65425.56
# 5    14 ST-UNION SQ  58387.24
# 6   42 ST-PORT AUTH  47439.76
# 7         FULTON ST  47114.68
# 8             86 ST  46530.08
# 9          CANAL ST  44600.80
# 10   47-50 STS ROCK  44236.08
# 11   59 ST COLUMBUS  41370.80
# 12            59 ST  37397.68
# 13           125 ST  35607.88
# 14      CHAMBERS ST  34598.04

# %%
plt.figure(figsize=(10,10))
top_ten_morning_rush_station = top_station_means_morning_rush_df[0:10]
plt.barh(top_ten_morning_rush_station['STATION'],top_ten_morning_rush_station['mean'])
plt.xlabel('Number of People')
plt.ylabel('Station')
plt.title('Top 10 Stations With Highest Traffic in Morning Rush')
for i, v in enumerate(top_ten_morning_rush_station['mean']):
    plt.text(v-8000, i-0.1, str(np.round(v)), color='white', fontweight='bold')

# %%
plt.figure(figsize=(20,10))

top_ten_morning_rush_station = station_mean_totals_df_morning_rush.sort_values(by=['USERS'], ascending=False)

#cat = ['YORK ST', '30 AV', '57 ST-7 AV', '34 ST-HERALD SQ', 'HIGH ST' , 'NOSTRAND AV', 'MYRTLE AV', 'HOYT-SCHER',
#       '42 ST-BRYANT PK', 'ASTORIA DITMARS' ]

cat = ['34 ST-PENN STA', 'GRD CNTRL-42 ST', '34 ST-HERALD SQ', 'TIMES SQ-42 ST', '23 ST', '47-50 STS ROCK', 
       '14 ST-UNION SQ', '42 ST-PORT AUTH', '86 ST', 'FULTON ST']

top_ten_morning_rush_station = top_ten_morning_rush_station.loc[top_ten_morning_rush_station['STATION'].isin(cat)]
top_ten_morning_rush_station.sort_values

ax = sns.boxplot(top_ten_morning_rush_station['STATION'],top_ten_morning_rush_station['USERS'], order=cat)
ax.set_title('Station Traffic During Morning Rush Hours on Weekdays')

medians = top_ten_morning_rush_station.groupby(['STATION'])['USERS'].median()
median_labels = [str(np.round(s)) for s in medians]

pos = range(len(medians))
#for tick,label in zip(pos,ax.get_xticklabels()):
#    plt.text(pos[tick], medians[label.get_text()]-2000, str(np.round(medians[label.get_text()])), 
#            horizontalalignment='center', size='large', color='w', weight='semibold')
for tick,label in zip(pos,ax.get_xticklabels()):
    plt.text(pos[tick], 88000, str(np.round(medians[label.get_text()])), 
            horizontalalignment='center', size='large', color='black', weight='semibold')

# %%
plt.figure(figsize=(10,10))
top_ten_afternoon_rush_station = top_station_means_afternoon_rush_df[0:10]
plt.barh(top_ten_afternoon_rush_station['STATION'],top_ten_afternoon_rush_station['mean'], color='orange')
plt.xlabel('Number of People')
plt.ylabel('Station')
plt.title('Top 10 Stations With Highest Traffic in Afternoon Rush')
for i, v in enumerate(top_ten_afternoon_rush_station['mean']):
    plt.text(v-9000, i-0.1, str(np.round(v)), color='white', fontweight='bold')

# %%
plt.figure(figsize=(20,10))

top_ten_afternoon_rush_station = station_mean_totals_df_afternoon_rush.sort_values(by=['USERS'], ascending=False)

#cat = ['YORK ST', '57 ST-7 AV', '34 ST-HERALD SQ', '14 ST-UNION SQ', '42 ST-BRYANT PK', 'W 4 ST-WASH SQ', 'GRD CNTRL-42 ST',
#      'HOYT-SCHER', 'TIMES SQ-42 ST', 'HIGH ST']

cat = ['34 ST-PENN STA', 'GRD CNTRL-42 ST', '34 ST-HERALD SQ', 'TIMES SQ-42 ST', '23 ST', '14 ST-UNION SQ', 
       '42 ST-PORT AUTH', 'FULTON ST', '86 ST', 'CANAL ST']

top_ten_afternoon_rush_station = top_ten_afternoon_rush_station.loc[top_ten_afternoon_rush_station['STATION'].isin(cat)]

ax = sns.boxplot(top_ten_afternoon_rush_station['STATION'],top_ten_afternoon_rush_station['USERS'], order=cat)
ax.set_title('Station Traffic During Afternoon Rush Hours on Weekdays')

medians = top_ten_afternoon_rush_station.groupby(['STATION'])['USERS'].median()
median_labels = [str(np.round(s)) for s in medians]

pos = range(len(medians))
#for tick,label in zip(pos,ax.get_xticklabels()):
#    plt.text(pos[tick], medians[label.get_text()]-2600, str(np.round(medians[label.get_text()])), 
#            horizontalalignment='center', size='large', color='w', weight='semibold')
    
for tick,label in zip(pos,ax.get_xticklabels()):
    plt.text(pos[tick], 115500, str(np.round(medians[label.get_text()])), 
             horizontalalignment='center', size='large', color='black', weight='semibold')

# %%
top_five_station = new_df[new_df['STATION'].isin(list(station_df[0:5]['STATION']))]
top_five_station_weekday = top_five_station.groupby(['STATION','WEEKDAY', 'WEEKDAYNUM']).TOTALS.mean().reset_index()
plt.figure(figsize=(12,8))
sns.barplot(x = 'STATION', y='TOTALS', hue='WEEKDAY' , data=top_five_station_weekday, hue_order=['Sunday','Monday','Tuesday','Wednesday','Thursday','Friday','Saturday'])
plt.ylabel('Mean', size=14)
plt.title('Mean Traffic at Top 5 Stations', size='14')
# Out:
# Text(0.5, 1.0, 'Mean Traffic at Top 5 Stations')

# %%
top_five_station_timebin_friday = top_five_station[top_five_station['WEEKDAY']=='Friday'].groupby(['STATION','TIME']).TOTALS.mean().reset_index()
top_five_station_timebin_friday.head(15)
# Out:
#            STATION              TIME       TOTALS
# 0            23 ST   4:00pm - 8:00pm   840.191667
# 1            23 ST  8:00am - 12:00am   652.796657
# 2  34 ST-HERALD SQ   4:00pm - 8:00pm  1516.649805
# 3  34 ST-HERALD SQ  8:00am - 12:00am  1090.034884
# 4   34 ST-PENN STA   4:00pm - 8:00pm   918.376016
# 5   34 ST-PENN STA  8:00am - 12:00am   685.686833
# 6  GRD CNTRL-42 ST   4:00pm - 8:00pm  1277.987461
# 7  GRD CNTRL-42 ST  8:00am - 12:00am   536.914692
# 8   TIMES SQ-42 ST   4:00pm - 8:00pm  1292.440816
# 9   TIMES SQ-42 ST  8:00am - 12:00am   716.341463

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'STATION', y='TOTALS', hue='TIME' , data=top_five_station_timebin_friday, hue_order=['8:00am - 12:00am','4:00pm - 8:00pm'])
plt.ylabel('Mean', size=14)
plt.title('Mean Traffic on Fridays at Top 5 Stations', size='14')
# Out:
# Text(0.5, 1.0, 'Mean Traffic on Fridays at Top 5 Stations')

# %%
top_five_station_weekday = top_five_station_weekday.sort_values(by=['WEEKDAYNUM'])
#top_five_station_weekday= top_five_station_weekday.drop('WEEKDAYNUM', axis=1)
top_five_station_weekday.head(15)
# Out:
#             STATION    WEEKDAY  WEEKDAYNUM       TOTALS
# 1             23 ST     Monday           0   680.369081
# 29   TIMES SQ-42 ST     Monday           0   934.640832
# 22  GRD CNTRL-42 ST     Monday           0  1083.942308
# 15   34 ST-PENN STA     Monday           0   761.569733
# 8   34 ST-HERALD SQ     Monday           0  1181.017613
# 26  GRD CNTRL-42 ST    Tuesday           1  1328.423780
# 33   TIMES SQ-42 ST    Tuesday           1  1223.542857
# 5             23 ST    Tuesday           1   785.322237
# 12  34 ST-HERALD SQ    Tuesday           1  1371.849237
# 19   34 ST-PENN STA    Tuesday           1   872.363902
# 13  34 ST-HERALD SQ  Wednesday           2  1411.502868
# 34   TIMES SQ-42 ST  Wednesday           2  1198.244660
# 27  GRD CNTRL-42 ST  Wednesday           2  1309.063893
# 6             23 ST  Wednesday           2   812.277632
# 20   34 ST-PENN STA  Wednesday           2   921.551935

# %%
cats = ['Monday', 'Tuesday', 'Wednesday', 'Thursday','Friday', 'Saturday', 'Sunday']
top_five_station_weekday['WEEKDAY'] = pd.Categorical(top_five_station_weekday['WEEKDAY'], ordered=True, categories=cats)

plt.figure(figsize=(12,8))
sns.lineplot(x = 'WEEKDAY', y='TOTALS', hue='STATION' , data=top_five_station_weekday)
plt.ylabel('Mean', size=14)
plt.title('Mean Traffic vs. Day of Week at Top 5 Stations', size='14')
# Out:
# Text(0.5, 1.0, 'Mean Traffic vs. Day of Week at Top 5 Stations')
